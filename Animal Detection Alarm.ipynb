# %%
import cv2 
import time
import matplotlib.pyplot as plt

import serial
import time

#arduino = serial.Serial(port='COM3', baudrate=9600, timeout=.1)

def sent_data():
    value = write_read(num)
    print(value)
config_file ='ssd_mobilenet_v3_large_coco_2020_01_14.pbtxt'
frozen_model = 'frozen_inference_graph.pb'

model=cv2.dnn_DetectionModel(frozen_model,config_file)

classLabels = []
file_name = 'Label.txt'
with open(file_name,'rt') as fpt:
    classLabels = fpt.read().rstrip('\n').split('\n')

print(classLabels)

print(len(classLabels))

model.setInputSize(320,320)
model.setInputScale(1.0/127.5)
model.setInputMean((127.5,127.5,127.5))
model.setInputSwapRB(True)

cap=cv2.VideoCapture(0)

if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open video")
frame_width  = int(cap.get(3))
frame_height = int(cap.get(4))

size = (frame_width, frame_height) 
    
font_scale = 3
font = cv2.FONT_HERSHEY_PLAIN

while True:
    num = '0'
    ret,frame = cap.read()
    
    ClassIndex, confidence, bbox = model.detect(frame,confThreshold=0.55)
    print(ClassIndex)
    if(len(ClassIndex)!=0):
        for ClassInd, conf, boxes in zip(ClassIndex.flatten(), confidence.flatten(), bbox):
            if(ClassInd<=80):
                cv2.rectangle(frame,boxes,(255, 0, 0), 2 )
                cv2.putText(frame,classLabels[ClassInd-1],(boxes[0]+10,boxes[1]+40), font, fontScale=font_scale,color=(0, 255, 0), thickness=3)
                print(classLabels[ClassInd-1])
                if classLabels[ClassInd-1] == 'animal':
                    print ("Human Activity Detected...!")
                    num =  '1'
                else :
                    num =  '0'
    cv2.imshow('Show',frame)
    #arduino.write(bytes(num, 'utf-8'))
    #time.sleep(0.0)
    #data = arduino.readline()
    #print(data)
    if cv2.waitKey(2) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# ['person', 'bicycle', 'car', 'motorbike', 'aeroplane', 'bus', 'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', 'animal', 'animal', 'animal', 'animal', 'animal', 'animal', 'animal', 'animal', 'animal', 'animal', 'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake', 'chair', 'sofa', 'pottedplant', 'bed', 'diningtable', 'toilet', 'tvmonitor', 'refrigerator', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'laptop', 'book', 'clock', 'vase', 'Mobile Phone', 'teddy bear', 'hair drier', 'toothbrush']
# 80
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [77  1 62 62]
# Mobile Phone
# person
# toilet
# toilet
# [77  1 77]
# Mobile Phone
# person
# Mobile Phone
# [77 77  1 62]
# Mobile Phone
# Mobile Phone
# person
# toilet
# [77 77  1 62]
# Mobile Phone
# Mobile Phone
# person
# toilet
# [77 77  1]
# Mobile Phone
# Mobile Phone
# person
# [77 77  1]
# Mobile Phone
# Mobile Phone
# person
# [77  1 77]
# Mobile Phone
# person
# Mobile Phone
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 77]
# person
# Mobile Phone
# [1]
# person
# [1]
# person
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [1]
# person
# [ 1 62 62]
# person
# toilet
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 72]
# person
# sink
# [ 1 72 62]
# person
# sink
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 72]
# person
# sink
# [ 1 72]
# person
# sink
# [ 1 62]
# person
# toilet
# [ 1 72 62]
# person
# sink
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 72]
# person
# sink
# [1]
# person
# [1]
# person
# [1]
# person
# [1]
# person
# [1]
# person
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 72 62]
# person
# sink
# toilet
# [ 1 72]
# person
# sink
# [ 1 62]
# person
# toilet
# [ 1 62 72]
# person
# toilet
# sink
# [ 1 62 72]
# person
# toilet
# sink
# [ 1 72]
# person
# sink
# [ 1 62 72]
# person
# toilet
# sink
# [ 1 62]
# person
# toilet
# [ 1 62 72 62]
# person
# toilet
# sink
# toilet
# [ 1 62 72 62]
# person
# toilet
# sink
# toilet
# [ 1 72]
# person
# sink
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [77  1 62]
# Mobile Phone
# person
# toilet
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1 62]
# Mobile Phone
# person
# toilet
# [77  1 62]
# Mobile Phone
# person
# toilet
# [ 1 77 62]
# person
# Mobile Phone
# toilet
# [77  1 62]
# Mobile Phone
# person
# toilet
# [77  1 62]
# Mobile Phone
# person
# toilet
# [1]
# person
# [ 1 77]
# person
# Mobile Phone
# [77  1]
# Mobile Phone
# person
# [ 1 77 62]
# person
# Mobile Phone
# toilet
# [77  1]
# Mobile Phone
# person
# [ 1 77]
# person
# Mobile Phone
# [ 1 62]
# person
# toilet
# [ 1 62 33]
# person
# toilet
# sports ball
# [ 1 33]
# person
# sports ball
# [ 1 62 33]
# person
# toilet
# sports ball
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 33]
# person
# sports ball
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62 33]
# person
# toilet
# sports ball
# [ 1 62]
# person
# toilet
# [ 1 62 33]
# person
# toilet
# sports ball
# [ 1 33]
# person
# sports ball
# [ 1 62 33]
# person
# toilet
# sports ball
# [ 1 33]
# person
# sports ball
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 33 62]
# person
# sports ball
# toilet
# [ 1 62 33]
# person
# toilet
# sports ball
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [62  1]
# toilet
# person
# [77  1]
# Mobile Phone
# person
# [77  1 62]
# Mobile Phone
# person
# toilet
# [77  1 62]
# Mobile Phone
# person
# toilet
# [77  1]
# Mobile Phone
# person
# [77  1 72]
# Mobile Phone
# person
# sink
# [77  1  1]
# Mobile Phone
# person
# person
# [77  1 77 75]
# Mobile Phone
# person
# Mobile Phone
# clock
# [1]
# person
# [1]
# person
# [77  1 77]
# Mobile Phone
# person
# Mobile Phone
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1 84]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1 75]
# Mobile Phone
# person
# clock
# [77  1 62]
# Mobile Phone
# person
# toilet
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1 75]
# Mobile Phone
# person
# clock
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1 72 84]
# Mobile Phone
# person
# sink
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1 75]
# Mobile Phone
# person
# clock
# [77  1]
# Mobile Phone
# person
# [77  1]
# Mobile Phone
# person
# [77  1 47]
# Mobile Phone
# person
# banana
# [ 1 62]
# person
# toilet
# [1]
# person
# [1]
# person
# [62  1 72 77]
# toilet
# person
# sink
# Mobile Phone
# [1]
# person
# [ 1 62  1]
# person
# toilet
# person
# [1]
# person
# [1]
# person
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [62  1 62]
# toilet
# person
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [62  1 62 62]
# toilet
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [62  1 62 62]
# toilet
# person
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [62  1 62 62]
# toilet
# person
# toilet
# toilet
# [ 1 62 62 84]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [62  1 62 62]
# toilet
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62 62]
# person
# toilet
# toilet
# toilet
# [ 1 62]
# person
# toilet
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62 62 77]
# person
# toilet
# toilet
# toilet
# Mobile Phone
# [ 1 62]
# person
# toilet
# [1]
# person
# [ 1 62]
# person
# toilet
# [ 1 62 62]
# person
# toilet
# toilet
# [ 1 62 62]
# person
# toilet
# toilet

# %%
# Python program to save a
# video using OpenCV


import cv2


# Create an object to read
# from camera
video = cv2.VideoCapture(0)

# We need to check if camera
# is opened previously or not
if (video.isOpened() == False):
	print("Error reading video file")

# We need to set resolutions.
# so, convert them from float to integer.
frame_width = int(video.get(3))
frame_height = int(video.get(4))

size = (frame_width, frame_height)

# Below VideoWriter object will create
# a frame of above defined The output
# is stored in 'filename.avi' file.
result = cv2.VideoWriter('filename.avi',
						cv2.VideoWriter_fourcc(*'MJPG'),
						10, size)
	
while(True):
	ret, frame = video.read()

	if ret == True:

		# Write the frame into the
		# file 'filename.avi'
		result.write(frame)

		# Display the frame
		# saved in the file
		cv2.imshow('Frame', frame)

	 	# Press S on keyboard
		# to stop the process
		if cv2.waitKey(1) & 0xFF == ord('s'):
			break

	 # Break the loop
	else:
		break

# When everything done, release
# the video capture and video
# write objects
video.release()
result.release()
	
# Closes all the frames
cv2.destroyAllWindows()

print("The video was successfully saved")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15696\3817061690.py in <module>
#      25 # a frame of above defined The output
#      26 # is stored in 'filename.avi' file.
# ---> 27 result = cv2.VideoWriter('filename.avi',
#      28                                                 cv2.VideoWriter_fourcc(*'MJPG'),
#      29 						10, size)
#
# KeyboardInterrupt:
